# %%
import pandas as pd

# %%
ratings = pd.read_csv('ratings_updated.csv')
users = pd.read_csv('users.csv')

# %% [markdown]
# # the goal here is to split the users into 10 groups
# ## Then each group will have a subset of the ratings matrix of just those users

# %%
def get_ratings_subset(block):
    
    block.set_index('userId', inplace=True)
    block = block[['rated_count']]
    
    new_df = ratings.join(block, on='userId', how='left')
    new_df.dropna(inplace=True)
    new_df.drop('rated_count', axis=1, inplace=True)
    new_df.drop('timestamp', axis=1, inplace=True)
    return new_df

# %%
users.shape
# Out:
# (138493, 3)

# %%
138493 / 10
# Out:
# 13849.3

# %% [markdown]
#  # iloc these
#  1. [0:13850]
#  2. [13850:27700]
#  3. [27700:41550]
#  4. [41550:55400]
#  5. [55400:69250]
#  6. [69250:83100]
#  7. [83100:96950]
#  8. [96950:110800]
#  9. [110800:124650]
#  10. [124650:138492]

# %%
users.sort_values('userId', ascending=True, inplace=True)

# %%
get_ratings_subset(users.iloc[0:13850]).to_csv('Collab_sets/block1.csv', index=False)

# %%
get_ratings_subset(users.iloc[13850:27700]).to_csv('Collab_sets/block2.csv', index=False)

# %%
get_ratings_subset(users.iloc[27700:41550]).to_csv('Collab_sets/block3.csv', index=False)

# %%
isthisworking = get_ratings_subset(users.iloc[41550:55400])

# %%
isthisworking.to_csv('Collab_sets/block4.csv', index=False)

# %%
get_ratings_subset(users.iloc[55400:69250]).to_csv('Collab_sets/block5.csv', index=False)

# %%
get_ratings_subset(users.iloc[69250:83100]).to_csv('Collab_sets/block6.csv', index=False)

# %%
get_ratings_subset(users.iloc[83100:96950]).to_csv('Collab_sets/block7.csv', index=False)

# %%
#block 8
get_ratings_subset(users.iloc[96950:110800]).to_csv('Collab_sets/block8.csv', index=False)

# %%
#block 9
get_ratings_subset(users.iloc[110800:124650]).to_csv('Collab_sets/block9.csv', index=False)

# %%
#block 10
get_ratings_subset(users.iloc[124650:138492]).to_csv('Collab_sets/block10.csv', index=False)

# %%
print('done!')
# Out:
# done!

# %%
# that didn't work, 100 groups, reload the users csv first
users = pd.read_csv('users.csv')

# %%
for i in range(100):
    
    temp_list = []
    for num in range(i, 138493, 100):
        temp_list.append(num)
    
    df = get_ratings_subset(users.loc[temp_list])
    
    filepath = 'Collab_sets/block' + str(i) + '.csv'
    df.to_csv(filepath, index=False)
    
    print(filepath, " ", len(temp_list))
# Out:
# Collab_sets/block0.csv   1385
# Collab_sets/block1.csv   1385
# Collab_sets/block2.csv   1385
# Collab_sets/block3.csv   1385
# Collab_sets/block4.csv   1385
# Collab_sets/block5.csv   1385
# Collab_sets/block6.csv   1385
# Collab_sets/block7.csv   1385
# Collab_sets/block8.csv   1385
# Collab_sets/block9.csv   1385
# Collab_sets/block10.csv   1385
# Collab_sets/block11.csv   1385
# Collab_sets/block12.csv   1385
# Collab_sets/block13.csv   1385
# Collab_sets/block14.csv   1385
# Collab_sets/block15.csv   1385
# Collab_sets/block16.csv   1385
# Collab_sets/block17.csv   1385
# Collab_sets/block18.csv   1385
# Collab_sets/block19.csv   1385
# Collab_sets/block20.csv   1385
# Collab_sets/block21.csv   1385
# Collab_sets/block22.csv   1385
# Collab_sets/block23.csv   1385
# Collab_sets/block24.csv   1385
# Collab_sets/block25.csv   1385
# Collab_sets/block26.csv   1385
# Collab_sets/block27.csv   1385
# Collab_sets/block28.csv   1385
# Collab_sets/block29.csv   1385
# Collab_sets/block30.csv   1385
# Collab_sets/block31.csv   1385
# Collab_sets/block32.csv   1385
# Collab_sets/block33.csv   1385
# Collab_sets/block34.csv   1385
# Collab_sets/block35.csv   1385
# Collab_sets/block36.csv   1385
# Collab_sets/block37.csv   1385
# Collab_sets/block38.csv   1385
# Collab_sets/block39.csv   1385
# Collab_sets/block40.csv   1385
# Collab_sets/block41.csv   1385
# Collab_sets/block42.csv   1385
# Collab_sets/block43.csv   1385
# Collab_sets/block44.csv   1385
# Collab_sets/block45.csv   1385
# Collab_sets/block46.csv   1385
# Collab_sets/block47.csv   1385
# Collab_sets/block48.csv   1385
# Collab_sets/block49.csv   1385
# Collab_sets/block50.csv   1385
# Collab_sets/block51.csv   1385
# Collab_sets/block52.csv   1385
# Collab_sets/block53.csv   1385
# Collab_sets/block54.csv   1385
# Collab_sets/block55.csv   1385
# Collab_sets/block56.csv   1385
# Collab_sets/block57.csv   1385
# Collab_sets/block58.csv   1385
# Collab_sets/block59.csv   1385
# Collab_sets/block60.csv   1385
# Collab_sets/block61.csv   1385
# Collab_sets/block62.csv   1385
# Collab_sets/block63.csv   1385
# Collab_sets/block64.csv   1385
# Collab_sets/block65.csv   1385
# Collab_sets/block66.csv   1385
# Collab_sets/block67.csv   1385
# Collab_sets/block68.csv   1385
# Collab_sets/block69.csv   1385
# Collab_sets/block70.csv   1385
# Collab_sets/block71.csv   1385
# Collab_sets/block72.csv   1385
# Collab_sets/block73.csv   1385
# Collab_sets/block74.csv   1385
# Collab_sets/block75.csv   1385
# Collab_sets/block76.csv   1385
# Collab_sets/block77.csv   1385
# Collab_sets/block78.csv   1385
# Collab_sets/block79.csv   1385
# Collab_sets/block80.csv   1385
# Collab_sets/block81.csv   1385
# Collab_sets/block82.csv   1385
# Collab_sets/block83.csv   1385
# Collab_sets/block84.csv   1385
# Collab_sets/block85.csv   1385
# Collab_sets/block86.csv   1385
# Collab_sets/block87.csv   1385
# Collab_sets/block88.csv   1385
# Collab_sets/block89.csv   1385
# Collab_sets/block90.csv   1385
# Collab_sets/block91.csv   1385
# Collab_sets/block92.csv   1385
# Collab_sets/block93.csv   1384
# Collab_sets/block94.csv   1384
# Collab_sets/block95.csv   1384
# Collab_sets/block96.csv   1384
# Collab_sets/block97.csv   1384
# Collab_sets/block98.csv   1384
# Collab_sets/block99.csv   1384

# %%
print('done')
# Out:
# done

# %%
pd.read_csv('Collab_sets/block2.csv')
# Out:
#         userId  movieId  rating
# 0          112        3     2.5
# 1          112       36     4.5
# 2          112       47     3.5
# 3          112       50     3.5
# 4          112      104     2.5
# 5          112      223     3.0
# 6          112      235     4.0
# 7          112      296     3.5
# 8          112      318     4.0
# 9          112      319     2.5
# 10         112      321     4.0
# 11         112      337     3.5
# 12         112      457     4.0
# 13         112      475     4.5
