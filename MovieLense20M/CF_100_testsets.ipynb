# %%
from surprise.dataset import Reader
from surprise import SVD
from surprise import Dataset
from surprise import dump

from collections import defaultdict
import pandas as pd

# %%
def get_top_n(predictions, n=10):
    '''Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    '''

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %% [markdown]
# # DONT RUN THESE AGAIN

# %%
#this reads the train set
reader = Reader(line_format='user item rating', sep=',', skip_lines=1)
filepath = 'train_ratings.csv'
data = Dataset.load_from_file(filepath, reader=reader)
trainset = data.build_full_trainset()

# %%
# First train an SVD algorithm on the full dataset.
algo = SVD()
algo.train(trainset)

# %%
dump.dump('CF_full_fit.pkl', algo=algo)

# %% [markdown]
# # Start Here

# %%
#reads in the testset
reader = Reader(line_format='user item rating', sep=',', skip_lines=1)
filepath_test = 'collab_test_ratings.csv'
data = Dataset.load_from_file(filepath_test, reader=reader)

# %%
#temperary step to build the testset
_ = data.build_full_trainset()

# %%
#this is the actual test set
testset = _.build_anti_testset()

# %%
__, loaded_algo = dump.load('CF_full_fit.pkl')

# %%
# We now ensure that the algo is still the same by checking the predictions.
predictions = loaded_algo.test(testset)

# %%
# filters predictions to the top 10
top_n = get_top_n(predictions, n=10)

# %%
df2 = pd.DataFrame().from_dict(top_n, orient='index')

# %%
df2.to_csv('top10_users.csv')

# %%
df2.head()
# Out:
#                          0                        1                       2  \
# 60     (82, 4.76144546839)    (1216, 4.75925738403)  (54190, 4.75363635523)
# 198  (5767, 4.68374754903)     (1080, 4.6186488884)  (66934, 4.61086350955)
# 211  (2324, 4.63888324971)  (116797, 4.61706171986)  (92259, 4.60663971857)
# 325  (4993, 4.90320428575)    (7153, 4.86141132778)   (5952, 4.83191611631)
# 411     (1, 4.58232073813)   (91233, 4.58051815827)    (527, 4.48260228142)
#
#                           3                       4                        5  \
# 60    (1172, 4.74032341364)   (7669, 4.72762369289)   (59387, 4.71401893956)
# 198    (318, 4.60622884494)    (665, 4.59285637343)  (104069, 4.56650356715)
# 211  (27523, 4.55160732108)  (91529, 4.53849521653)   (27815, 4.53539217627)
# 325    (318, 4.74999105717)  (79132, 4.66511341392)     (527, 4.65065235766)
# 411   (3114, 4.47769567084)   (8827, 4.47414513186)     (318, 4.45758930736)
#
#                           6                        7                      8  \
# 60   (87308, 4.70888736644)    (4973, 4.67009398763)  (2686, 4.66541648749)
# 198   (1202, 4.56557128667)     (858, 4.54589867984)  (1136, 4.51519807534)
# 211  (73881, 4.52514617194)   (72998, 4.52028458813)  (1797, 4.46864322521)
# 325   (3578, 4.64052217904)  (109487, 4.63843238315)  (2028, 4.61248773355)
# 411   (1148, 4.44653278145)    (4896, 4.44525753549)   (150, 4.44236570367)
#
#                           9
# 60   (64034, 4.64303660831)
# 198  (31359, 4.51332941718)
# 211  (88810, 4.46775340424)
# 325   (2571, 4.58689616013)
# 411  (78499, 4.41820764851)

# %%
df2.shape
# Out:
# (1385, 10)

# %%
df_read = pd.read_csv('top10_users.csv')

# %%
df_read
# Out:
#       Unnamed: 0                               0  \
# 0             60      ('82', 4.7614454683856051)
# 1            198    ('5767', 4.6837475490285696)
# 2            211    ('2324', 4.6388832497053087)
# 3            325    ('4993', 4.9032042857481111)
# 4            411       ('1', 4.5823207381265822)
# 5            527    ('1900', 4.6228528014505725)
# 6            595     ('946', 4.7791213730638189)
# 7            647    ('92535', 4.431162618296228)
# 8            712   ('27611', 4.1953332617592931)
# 9            926    ('1148', 4.9157940092790628)
# 10           933    ('1148', 4.7325305975733896)
# 11           986                    ('44555', 5)
# 12          1217                     ('4896', 5)
# 13          1260    ('3868', 4.6430198904034032)
# 14          1261   ('58559', 4.6288727980181559)
# 15          1281    ('2324', 4.6878552632608317)
# 16          1298    ('1221', 4.6131975222044055)
# 17          1450   ('60904', 4.5371378757197318)
# 18          1510   ('26587', 4.5086412662888211)
# 19          1567                    ('92535', 5)
# 20          1606                    ('94466', 5)
# 21          1670   ('92535', 4.5997479968994863)
# 22          1747   ('91529', 4.7866926454352807)
# 23          1801    ('4973', 4.6939434726798428)
# 24          1868   ('40815', 4.8407710616491695)
# 25          1929     ('318', 4.7001235962773169)
# 26          1983    ('1206', 4.2434469107176032)
# 27          2166  ('112290', 4.0406609395048152)
# 28          2454                    ('72998', 5)
# 29          2458    ('4993', 4.6026978603300011)
# ...          ...                             ...
# 1355      134702     ('318', 4.6296060837293904)
# 1356      134767    ('4993', 3.6868731076807624)
# 1357      134812     ('215', 4.3191833179062842)
# 1358      134851                    ('58376', 5)
# 1359      134972    ('7669', 4.9872571047473677)
# 1360      134984     ('260', 4.8826507202694138)
# 1361      135191    ('89745', 3.840866325534154)
# 1362      135477    ('1354', 4.9960397695048613)
# 1363      135777  ('104069', 4.7165674970587403)
# 1364      135862    ('7669', 4.9966841720476403)
# 1365      135878    ('5952', 4.3900486012568969)
# 1366      135961   ('55721', 3.7755075964399687)
# 1367      136157   ('60904', 4.0982345208425457)
# 1368      136160                      ('318', 5)
# 1369      136334                     ('2360', 5)
# 1370      136338    ('26133', 4.200960327368815)
# 1371      136424     ('318', 4.8341920680980808)
# 1372      136437   ('92259', 4.3894444180514824)
# 1373      136590                     ('7361', 5)
# 1374      136647    ('1148', 4.9281423119159919)
# 1375      136746    ('8533', 4.1657694985281744)
# 1376      137385     ('318', 4.3820581294534975)
# 1377      137477    ('1207', 4.4261497202955384)
# 1378      137580   ('92259', 4.5631065817823542)
# 1379      137634                      ('593', 5)
# 1380      137976                     ('3022', 5)
# 1381      138048                      ('527', 5)
# 1382      138066                      ('296', 5)
# 1383      138122     ('318', 4.4313729968889106)
# 1384      138317    ('1148', 3.6255695575738098)
#
#                                    1                               2  \
# 0       ('1216', 4.7592573840297758)   ('54190', 4.7536363552273153)
# 1       ('1080', 4.6186488884024772)   ('66934', 4.6108635095522805)
# 2     ('116797', 4.6170617198591088)   ('92259', 4.6066397185668482)
# 3       ('7153', 4.8614113277826059)    ('5952', 4.8319161163059894)
# 4        ('91233', 4.58051815826673)     ('527', 4.4826022814171953)
# 5        ('214', 4.6064703745041236)    ('7327', 4.5847123374038983)
# 1361   ('26614', 3.6452787390073476)
# 1362    ('1221', 4.8965292714024615)
# 1363    ('6016', 4.5161601329384542)
# 1364   ('88810', 4.5775744713511628)
# 1365       ('47', 4.073687528681349)
# 1366    ('2618', 3.7041505403400823)
# 1367    ('1214', 4.0352772581761132)
# 1368    ('8014', 4.9710647386357971)
# 1369    ('1228', 4.9905351371258275)
# 1370    ('6896', 4.0676020829413515)
# 1371     ('858', 4.6551050810273802)
# 1372   ('95377', 4.1316888111322783)
# 1373    ('2920', 4.9862166796183658)
# 1374    ('5952', 4.7145297952594483)
# 1375   ('32460', 4.0532345510362369)
# 1376     ('903', 4.1642446563417774)
# 1377    ('1204', 4.3294010317659932)
# 1378  ('116797', 4.3742064835299015)
# 1379                     ('1028', 5)
# 1380    ('52767', 4.758581347581833)
# 1381                   ('116797', 5)
# 1382                    ('48394', 5)
# 1383    ('5319', 4.2866628750695241)
# 1384      ('912', 3.558985293364552)
#
# [1385 rows x 11 columns]

# %% [markdown]
# # Now lets do that 10x

# %%
reader = Reader(line_format='user item rating', sep=',', skip_lines=1)

# %%
__, loaded_algo = dump.load('CF_full_fit.pkl')

# %%
for iteration in range(100):
    #get the data
    print(iteration, ": Loading block")
    filename = 'Batches/' + 'block' + str(iteration) + '.csv'
    data = Dataset.load_from_file(filename, reader=reader)
    
    #temperary step to build the testset
    print(iteration, ": processing testset")
    _ = data.build_full_trainset()
    #this is the actual test set
    testset = _.build_anti_testset()
    
    # We now ensure that the algo is still the same by checking the predictions.
    print(iteration, ": Predictions happening")
    predictions = loaded_algo.test(testset)
    
    # filters predictions to the top 10
    print(iteration, ": Getting top 10")
    top_n = get_top_n(predictions, n=10)
    
    df2 = pd.DataFrame().from_dict(top_n, orient='index')
    
    outputname = 'Batches/' +'output_' + 'block' + str(iteration) + '.csv'
    df2.to_csv(outputname)

    print(iteration, ": Finished!")
# Out:
# 0 : Loading block
# 0 : processing testset
# 0 : Predictions happening
# 0 : Getting top 10
# 0 : Finished!
# 1 : Loading block
# 1 : processing testset
# 1 : Predictions happening
# 1 : Getting top 10
# 1 : Finished!
# 2 : Loading block
# 2 : processing testset
# 2 : Predictions happening
# 2 : Getting top 10
# 2 : Finished!
# 3 : Loading block
# 3 : processing testset
# 3 : Predictions happening
# 3 : Getting top 10
# 3 : Finished!
# 4 : Loading block
# 4 : processing testset
# 4 : Predictions happening
# 4 : Getting top 10
# 4 : Finished!
# 5 : Loading block
# 5 : processing testset
# 5 : Predictions happening
# 5 : Getting top 10
# 5 : Finished!
# 6 : Loading block
# 6 : processing testset
# 6 : Predictions happening
# 6 : Getting top 10
# 6 : Finished!
# 7 : Loading block
# 7 : processing testset
# 7 : Predictions happening
# 7 : Getting top 10
# 7 : Finished!
# 8 : Loading block
# 8 : processing testset
# 8 : Predictions happening
# 8 : Getting top 10
# 8 : Finished!
# 9 : Loading block
# 9 : processing testset
# 9 : Predictions happening
# 9 : Getting top 10
# 9 : Finished!
# 10 : Loading block
# 10 : processing testset
# 10 : Predictions happening
# 10 : Getting top 10
# 10 : Finished!
# 11 : Loading block
# 11 : processing testset
# 11 : Predictions happening
# 11 : Getting top 10
# 11 : Finished!
# 12 : Loading block
# 12 : processing testset
# 12 : Predictions happening
# 12 : Getting top 10
# 12 : Finished!
# 13 : Loading block
# 13 : processing testset
# 13 : Predictions happening
# 13 : Getting top 10
# 13 : Finished!
# 14 : Loading block
# 14 : processing testset
# 14 : Predictions happening
# 14 : Getting top 10
# 14 : Finished!
# 15 : Loading block
# 15 : processing testset
# 15 : Predictions happening
# 15 : Getting top 10
# 15 : Finished!
# 16 : Loading block
# 16 : processing testset
# 16 : Predictions happening
# 16 : Getting top 10
# 16 : Finished!
# 17 : Loading block
# 17 : processing testset
# 17 : Predictions happening
# 17 : Getting top 10
# 17 : Finished!
# 18 : Loading block
# 18 : processing testset
# 18 : Predictions happening
# 18 : Getting top 10
# 18 : Finished!
# 19 : Loading block
# 19 : processing testset
# 19 : Predictions happening
# 19 : Getting top 10
# 19 : Finished!
# 20 : Loading block
# 20 : processing testset
# 20 : Predictions happening
# 20 : Getting top 10
# 20 : Finished!
# 21 : Loading block
# 21 : processing testset
# 21 : Predictions happening
# 21 : Getting top 10
# 21 : Finished!
# 22 : Loading block
# 22 : processing testset
# 22 : Predictions happening
# 22 : Getting top 10
# 22 : Finished!
# 23 : Loading block
# 23 : processing testset
# 23 : Predictions happening
# 23 : Getting top 10
# 23 : Finished!
# 24 : Loading block
# 24 : processing testset
# 24 : Predictions happening
# 24 : Getting top 10
# 24 : Finished!
# 25 : Loading block
# 25 : processing testset
# 25 : Predictions happening
# 25 : Getting top 10
# 25 : Finished!
# 26 : Loading block
# 26 : processing testset
# 26 : Predictions happening
# 26 : Getting top 10
# 26 : Finished!
# 27 : Loading block
# 27 : processing testset
# 27 : Predictions happening
# 27 : Getting top 10
# 27 : Finished!
# 28 : Loading block
# 28 : processing testset
# 28 : Predictions happening
# 28 : Getting top 10
# 28 : Finished!
# 29 : Loading block
# 29 : processing testset
# 29 : Predictions happening
# 29 : Getting top 10
# 29 : Finished!
# 30 : Loading block
# 30 : processing testset
# 30 : Predictions happening
# 30 : Getting top 10
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-1f0a128947fe> in <module>()
#      24
#      25     outputname = 'Batches/' +'output_' + 'block' + str(iteration) + '.csv'
# ---> 26     df2.to_csv(outputname)
#      27
#      28     print(iteration, ": Finished!")
#
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1411                                      doublequote=doublequote,
#    1412                                      escapechar=escapechar, decimal=decimal)
# -> 1413         formatter.save()
#    1414
#    1415         if path_or_buf is None:
#
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in save(self)
#    1581                 self.writer = csv.writer(f, **writer_kwargs)
#    1582
# -> 1583             self._save()
#    1584
#    1585         finally:
#
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in _save(self)
#    1682                 break
#    1683
# -> 1684             self._save_chunk(start_i, end_i)
#    1685
#    1686     def _save_chunk(self, start_i, end_i):
#
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/pandas/io/formats/format.py in _save_chunk(self, start_i, end_i)
#    1708                                         quoting=self.quoting)
#    1709
# -> 1710         lib.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#    1711
#    1712
#
# pandas/_libs/lib.pyx in pandas._libs.lib.write_csv_rows (pandas/_libs/lib.c:19647)()
#
# OSError: [Errno 28] No space left on device

# %%
# ERROR AT INDEX 30

# %%
# start at 30 now

for iteration in range(91, 100):
    #get the data
    print(iteration, ": Loading block")
    filename = 'Batches/' + 'block' + str(iteration) + '.csv'
    data = Dataset.load_from_file(filename, reader=reader)
    
    #temperary step to build the testset
    print(iteration, ": processing testset")
    _ = data.build_full_trainset()
    #this is the actual test set
    testset = _.build_anti_testset()
    
    # We now ensure that the algo is still the same by checking the predictions.
    print(iteration, ": Predictions happening")
    predictions = loaded_algo.test(testset)
    
    # filters predictions to the top 10
    print(iteration, ": Getting top 10")
    top_n = get_top_n(predictions, n=10)
    
    df2 = pd.DataFrame().from_dict(top_n, orient='index')
    
    outputname = 'Batches/' +'output_' + 'block' + str(iteration) + '.csv'
    df2.to_csv(outputname)

    print(iteration, ": Finished!")
# Out:
# 91 : Loading block
# 91 : processing testset
# 91 : Predictions happening
# 91 : Getting top 10
# 91 : Finished!
# 92 : Loading block
# 92 : processing testset
# 92 : Predictions happening
# 92 : Getting top 10
# 92 : Finished!
# 93 : Loading block
# 93 : processing testset
# 93 : Predictions happening
# 93 : Getting top 10
# 93 : Finished!
# 94 : Loading block
# 94 : processing testset
# 94 : Predictions happening
# 94 : Getting top 10
# 94 : Finished!
# 95 : Loading block
# 95 : processing testset
# 95 : Predictions happening
# 95 : Getting top 10
# 95 : Finished!
# 96 : Loading block
# 96 : processing testset
# 96 : Predictions happening
# 96 : Getting top 10
# 96 : Finished!
# 97 : Loading block
# 97 : processing testset
# 97 : Predictions happening
# 97 : Getting top 10
# 97 : Finished!
# 98 : Loading block
# 98 : processing testset
# 98 : Predictions happening
# 98 : Getting top 10
# 98 : Finished!
# 99 : Loading block
# 99 : processing testset
# 99 : Predictions happening
# 99 : Getting top 10
# 99 : Finished!

# %%
# so block0 is missing somehow

iteration = 0

#get the data
print(iteration, ": Loading block")
filename = 'Batches/' + 'block' + str(iteration) + '.csv'
data = Dataset.load_from_file(filename, reader=reader)

#temperary step to build the testset
print(iteration, ": processing testset")
_ = data.build_full_trainset()
#this is the actual test set
testset = _.build_anti_testset()

# We now ensure that the algo is still the same by checking the predictions.
print(iteration, ": Predictions happening")
predictions = loaded_algo.test(testset)

# filters predictions to the top 10
print(iteration, ": Getting top 10")
top_n = get_top_n(predictions, n=10)

df2 = pd.DataFrame().from_dict(top_n, orient='index')

outputname = 'Batches/' +'output_' + 'block' + str(iteration) + '.csv'
df2.to_csv(outputname)

print(iteration, ": Finished!")
# Out:
# 0 : Loading block
# 0 : processing testset
# 0 : Predictions happening
# 0 : Getting top 10
# 0 : Finished!

# %%
# another sidd note, this code ran from 0-90 on an EC2 t2.XLarge instance. it crashed at 91.

# %%
for x in range(3, 10):
    print(x)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9
